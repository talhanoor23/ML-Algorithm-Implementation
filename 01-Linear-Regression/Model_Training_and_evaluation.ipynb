# %% [markdown]
# <a href="https://colab.research.google.com/github/talhanoor23/ML-Algorithm-Implementation/blob/main/01-Linear-Regression/Model_Training_and_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Model Training**

# %%
from sklearn.linear_model import LinearRegression
Model = LinearRegression()

# %%
# %%time
Model.fit(train_inputs, train_targets)
# Out:
# CPU times: user 5.07 ms, sys: 691 µs, total: 5.76 ms
# Wall time: 6.03 ms
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
train_preds = Model.predict(train_inputs)
mse = mean_squared_error(train_targets, train_preds)
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 984051.9236507412

# %%
train_mae = mean_absolute_error(train_targets, train_preds)
print(f"Mean Absolute Error (MAE): {train_mae}")
# Out:
# Mean Absolute Error (MAE): 719242.8936724712

# %%
r2 = r2_score(train_targets, train_preds)
print(f"R² Score: {r2}")
# Out:
# R² Score: 0.6859438988560158

# %% [markdown]
# # **Model Predictions**

# %%
test_preds = Model.predict(test_inputs)

# %%
test_target_preds = pd.DataFrame({'Actual': test_targets, 'Predicted': test_preds})

# %%
test_target_preds.head()
# Out:
#       Actual     Predicted
# 316  4060000  5.164654e+06
# 77   6650000  7.224722e+06
# 360  3710000  3.109863e+06
# 90   6440000  4.612075e+06
# 493  2800000  3.294646e+06

# %%
test_mse = mean_squared_error(test_targets, test_preds)
test_rmse = np.sqrt(test_mse)
test_rmse
# Out:
# 1324506.9600914405

# %%
r2 = r2_score(test_targets, test_preds)
print(f"R² Score: {r2}")
# Out:
# R² Score: 0.6529242642153175

# %%
feature_importance = pd.DataFrame({'Feature' : train_inputs.columns, 'Importance' : Model.coef_})

# %%
feature_importance.sort_values(by='Importance', ascending=False)
# Out:
#                             Feature     Importance
# 2                         bathrooms  521879.027748
# 0                              area  519552.416340
# 14              airconditioning_yes  395713.367922
# 3                           stories  349251.438906
# 12              hotwaterheating_yes  342324.942669
# 16                     prefarea_yes  314945.282657
# 10                     basement_yes  195125.588091
# 4                           parking  192005.953667
# 6                      mainroad_yes  183959.973840
# 17       furnishingstatus_furnished  180175.626604
# 8                     guestroom_yes  115805.018588
# 1                          bedrooms   57349.559419
# 18  furnishingstatus_semi-furnished   53293.809019
# 7                      guestroom_no -115805.018588
# 5                       mainroad_no -183959.973840
# 9                       basement_no -195125.588091
# 19     furnishingstatus_unfurnished -233469.435624
# ...

# %%
Model.score(train_inputs, train_targets)
# Out:
# 0.6859438988560158

# %%
Model.score(test_inputs, test_targets)
# Out:
# 0.6529242642153175

# %%
import matplotlib.pyplot as plt

# Predict values for the test set
test_preds = Model.predict(test_inputs)

# Plot Actual vs. Predicted values
plt.figure(figsize=(10, 6))
plt.scatter(test_targets, test_preds, alpha=0.6, color='blue')
plt.plot([test_targets.min(), test_targets.max()], [test_targets.min(), test_targets.max()], color='red', linestyle='--', linewidth=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs. Predicted Prices')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Predict values for the test set
test_preds = Model.predict(test_inputs)

# Plot Actual vs. Predicted values
plt.figure(figsize=(10, 6))
plt.scatter(test_targets, test_preds, alpha=0.6, color='blue')
plt.plot([train_targets.min(), train_targets.max()], [train_targets.min(), train_targets.max()], color='red', linestyle='--', linewidth=4)
plt.plot([test_targets.min(), test_targets.max()], [test_targets.min(), test_targets.max()], color='green', linestyle='--', linewidth=2)
plt.plot([test_preds.min(), test_preds.max()], [test_preds.min(), test_preds.max()], color='blue', linestyle='--', linewidth=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs. Predicted Prices')
plt.grid(True)
plt.show()
